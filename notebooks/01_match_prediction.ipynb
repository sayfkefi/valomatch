# %%
import pandas as pd
df = pd.read_csv("../data/players_stats.csv")
df.head()
# Out:
#                 Tournament     Stage           Match Type Player  \
# 0  Valorant Champions 2025  Playoffs  Upper Quarterfinals    Boo
# 1  Valorant Champions 2025  Playoffs  Upper Quarterfinals    Boo
# 2  Valorant Champions 2025  Playoffs  Upper Quarterfinals    Boo
# 3  Valorant Champions 2025  Playoffs  Upper Quarterfinals  RieNs
# 4  Valorant Champions 2025  Playoffs  Upper Quarterfinals  RieNs
#
#            Teams       Agents  Rounds Played  Rating  Average Combat Score  \
# 0  Team Heretics        astra             26    0.68                 129.0
# 1  Team Heretics         omen             19    0.46                  98.0
# 2  Team Heretics  astra, omen             45    0.59                 114.0
# 3  Team Heretics         fade             26    1.21                 219.0
# 4  Team Heretics         sova             19    1.02                 220.0
#
#    Kills:Deaths  ... First Deaths Per Round  Headshot %  Clutch Success %  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17996 entries, 0 to 17995
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Tournament                      17996 non-null  str
#  1   Stage                           17996 non-null  str
#  2   Match Type                      17996 non-null  str
#  3   Player                          17996 non-null  str
#  4   Teams                           17996 non-null  str
#  5   Agents                          17996 non-null  str
#  6   Rounds Played                   17996 non-null  int64
#  7   Rating                          16604 non-null  float64
#  8   Average Combat Score            17986 non-null  float64
#  9   Kills:Deaths                    17996 non-null  float64
#  10  Kill, Assist, Trade, Survive %  16692 non-null  str
#  11  Average Damage Per Round        16626 non-null  float64
# ...

# %%
df_scores = pd.read_csv("../data/scores.csv")
df_scores.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2025  Group Stage  Opening (A)
# 1  Valorant Champions 2025  Group Stage  Opening (A)
# 2  Valorant Champions 2025  Group Stage  Opening (C)
# 3  Valorant Champions 2025  Group Stage  Opening (C)
# 4  Valorant Champions 2025  Group Stage  Opening (D)
#
#                    Match Name                Team A         Team B  \
# 0  Paper Rex vs Xi Lai Gaming             Paper Rex  Xi Lai Gaming
# 1         GIANTX vs Sentinels                GIANTX      Sentinels
# 2        NRG vs EDward Gaming           Mega Minors  EDward Gaming
# 3          Team Liquid vs DRX           Team Liquid            DRX
# 4  Dragon Ranger Gaming vs T1  Dragon Ranger Gaming             T1
#
#    Team A Score  Team B Score   Match Result
# 0             2             0  Paper Rex won
# 1             2             1     GIANTX won
# 2             2             0        NRG won
# 3             0             2        DRX won
# ...

# %%
df_scores.duplicated(subset=["Tournament", "Stage", "Match Type"]).sum()
# Out:
# np.int64(311)

# %%
df_scores.duplicated(subset=["Tournament", "Stage", "Match Name"]).sum()
# Out:
# np.int64(8)

# %%
df_scores.duplicated(subset=["Tournament", "Stage", "Match Type", "Match Name"]).sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Tournament', 'Stage', 'Match Type', 'Player', 'Teams', 'Agents',
#        'Rounds Played', 'Rating', 'Average Combat Score', 'Kills:Deaths',
#        'Kill, Assist, Trade, Survive %', 'Average Damage Per Round',
#        'Kills Per Round', 'Assists Per Round', 'First Kills Per Round',
#        'First Deaths Per Round', 'Headshot %', 'Clutch Success %',
#        'Clutches (won/played)', 'Maximum Kills in a Single Map', 'Kills',
#        'Deaths', 'Assists', 'First Kills', 'First Deaths'],
#       dtype='str')

# %%
df_teams = pd.read_csv("../data/team_mapping.csv")
df_teams.head()
# Out:
#   Abbreviated      Full Name
# 0         PRX      Paper Rex
# 1         XLG  Xi Lai Gaming
# 2          GX         GIANTX
# 3         SEN      Sentinels
# 4         NRG            NRG

# %%
"Mega Minors" in df_teams["Full Name"].values
# Out:
# False

# %%
"Mega Minors" in df_teams["Abbreviated"].values
# Out:
# False

# %%
df["Teams"].unique()
# Out:
# <StringArray>
# [                     'Team Heretics',                             'GIANTX',
#                          'G2 Esports',                               'MIBR',
#                                 'DRX',                             'FNATIC',
#                           'Paper Rex',                        'Mega Minors',
#                           'Sentinels',                      'Xi Lai Gaming',
#                     'Bilibili Gaming',                     'Rex Regum Qeon',
#                         'Team Liquid',                      'EDward Gaming',
#                'Dragon Ranger Gaming',                                 'T1',
#                         'BBL Esports',                      'Natus Vincere',
#                        'Karmine Corp',                      'Team Vitality',
#                        'Gentle Mates',                                'KOI',
#                         'FUT Esports',                              'Apeks',
# ...

# %%
df["Teams"].nunique()
# Out:
# 58

# %%
df["Teams"].str.contains(",").sum()
# Out:
# np.int64(58)

# %%
df_clean = df[~df["Teams"].str.contains(",")]

# %%
df.shape
# Out:
# (17996, 25)

# %%
df_clean.shape
# Out:
# (17938, 25)

# %%
df_clean["Teams"].unique()
# Out:
# <StringArray>
# [       'Team Heretics',               'GIANTX',           'G2 Esports',
#                  'MIBR',                  'DRX',               'FNATIC',
#             'Paper Rex',          'Mega Minors',            'Sentinels',
#         'Xi Lai Gaming',      'Bilibili Gaming',       'Rex Regum Qeon',
#           'Team Liquid',        'EDward Gaming', 'Dragon Ranger Gaming',
#                    'T1',          'BBL Esports',        'Natus Vincere',
#          'Karmine Corp',        'Team Vitality',         'Gentle Mates',
#                   'KOI',          'FUT Esports',                'Apeks',
#              'LEVIATÁN',          '100 Thieves',               'Cloud9',
#         'Evil Geniuses',          'KRÜ Esports',        '2Game Esports',
#                 'FURIA',                 'LOUD',    'Nongshim RedForce',
#                 'TALON',                'Gen.G',   'DetonatioN FocusMe',
#        'Global Esports',          'Team Secret',        'ZETA DIVISION',
# ...

# %%
df_scores["Team A"].unique()
# Out:
# <StringArray>
# [           'Paper Rex',               'GIANTX',          'Mega Minors',
#           'Team Liquid', 'Dragon Ranger Gaming',           'G2 Esports',
#       'Bilibili Gaming',       'Rex Regum Qeon',                  'DRX',
#         'Team Heretics',                 'MIBR',        'Xi Lai Gaming',
#                    'T1',               'FNATIC',               'Cloud9',
#              'LEVIATÁN',        'Evil Geniuses',          '100 Thieves',
#             'Sentinels',        '2Game Esports',                'FURIA',
#                  'LOUD',          'KRÜ Esports',           'Team Alpha',
#         'Natus Vincere',        'Team Vitality',          'FUT Esports',
#                 'Apeks',         'Gentle Mates',                  'KOI',
#           'BBL Esports',          'Team France',         'BOOM Esports',
#     'Nongshim RedForce',        'ZETA DIVISION',       'Global Esports',
#                 'TALON',                'Gen.G',           'Team World',
# ...

# %%
df_scores["Team B"].unique()
# Out:
# <StringArray>
# [       'Xi Lai Gaming',            'Sentinels',        'EDward Gaming',
#                   'DRX',                   'T1',        'Team Heretics',
#                  'MIBR',               'FNATIC',               'GIANTX',
#           'Mega Minors',       'Rex Regum Qeon', 'Dragon Ranger Gaming',
#           'Team Liquid',           'G2 Esports',            'Paper Rex',
#                 'FURIA',                 'LOUD',        '2Game Esports',
#           'KRÜ Esports',        'Evil Geniuses',             'LEVIATÁN',
#                'Cloud9',          '100 Thieves',           'Team Omega',
#                 'Apeks',         'Gentle Mates',                  'KOI',
#           'BBL Esports',         'Karmine Corp',        'Natus Vincere',
#         'Team Vitality',            'Team EMEA',                'TALON',
#           'Team Secret',                'Gen.G',       'Global Esports',
#    'DetonatioN FocusMe',    'Nongshim RedForce',        'ZETA DIVISION',
# ...

# %%
pd.concat([df_scores["Team A"], df_scores["Team B"]])
# Out:
# 0                 Paper Rex
# 1                    GIANTX
# 2               Mega Minors
# 3               Team Liquid
# 4      Dragon Ranger Gaming
#                ...
# 498           Xi Lai Gaming
# 499           Trace Esports
# 500           EDward Gaming
# 501           EDward Gaming
# 502           EDward Gaming
# Length: 1006, dtype: str

# %%
teams_players = set(df_clean["Teams"].unique())

# %%
teams_players - set(pd.concat([df_scores["Team A"], df_scores["Team B"]]))
# Out:
# set()

# %%
"NRG" in teams_players
# Out:
# False

# %%
set(pd.concat([df_scores["Team A"], df_scores["Team B"]])) - teams_players
# Out:
# {'Glory Once Again',
#  'Precise Defeat',
#  'Pure Aim',
#  'Team Alpha',
#  'Team EMEA',
#  'Team France',
#  'Team International',
#  'Team Omega',
#  'Team Thailand',
#  'Team World'}

# %%
df_scores.columns
# Out:
# Index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Team A', 'Team B',
#        'Team A Score', 'Team B Score', 'Match Result'],
#       dtype='str')

# %%
side_a = df_scores.rename(columns={"Team A": "Teams","Team B": "opponent", "Team A Score": "team_score", "Team B Score": "opp_score"})

# %%
side_a.columns
# Out:
# Index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Teams', 'opponent',
#        'team_score', 'opp_score', 'Match Result'],
#       dtype='str')

# %%
side_b = df_scores.rename(columns={"Team B": "Teams","Team A": "opponent", "Team B Score": "team_score", "Team A Score": "opp_score"})

# %%
side_b.columns
# Out:
# Index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'opponent', 'Teams',
#        'opp_score', 'team_score', 'Match Result'],
#       dtype='str')

# %%
df_scores.shape
# Out:
# (503, 9)

# %%
scores_long = pd.concat([side_a, side_b], ignore_index=True)

# %%
scores_long.shape
# Out:
# (1006, 9)

# %%
scores_long.columns
# Out:
# Index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Teams', 'opponent',
#        'team_score', 'opp_score', 'Match Result'],
#       dtype='str')

# %%
scores_long["win"]= (scores_long["team_score"] > scores_long["opp_score"]).astype(int)

# %%
scores_long.columns
# Out:
# Index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Teams', 'opponent',
#        'team_score', 'opp_score', 'Match Result', 'win'],
#       dtype='str')

# %%
scores_long["win"].mean()
# Out:
# np.float64(0.5)

# %%
df_clean.columns
# Out:
# Index(['Tournament', 'Stage', 'Match Type', 'Player', 'Teams', 'Agents',
#        'Rounds Played', 'Rating', 'Average Combat Score', 'Kills:Deaths',
#        'Kill, Assist, Trade, Survive %', 'Average Damage Per Round',
#        'Kills Per Round', 'Assists Per Round', 'First Kills Per Round',
#        'First Deaths Per Round', 'Headshot %', 'Clutch Success %',
#        'Clutches (won/played)', 'Maximum Kills in a Single Map', 'Kills',
#        'Deaths', 'Assists', 'First Kills', 'First Deaths'],
#       dtype='str')

# %%
scores_long.columns
# Out:
# Index(['Tournament', 'Stage', 'Match Type', 'Match Name', 'Teams', 'opponent',
#        'team_score', 'opp_score', 'Match Result', 'win'],
#       dtype='str')

# %%
df_merged = pd.merge(df_clean, scores_long, on=['Tournament', 'Stage', 'Match Type', 'Teams'], how="left")

# %%
df_merged.shape
# Out:
# (18365, 31)

# %%
scores_long[scores_long.duplicated(subset=['Tournament', 'Stage', 'Match Type', 'Teams'], keep=False)]
# Out:
#                     Tournament        Stage Match Type  \
# 120  VCT 2025: Pacific Stage 2  Group Stage     Week 1
# 121  VCT 2025: Pacific Stage 2  Group Stage     Week 1
# 122  VCT 2025: Pacific Stage 2  Group Stage     Week 1
# 123  VCT 2025: Pacific Stage 2  Group Stage     Week 1
# 124  VCT 2025: Pacific Stage 2  Group Stage     Week 1
# 125  VCT 2025: Pacific Stage 2  Group Stage     Week 1
# 126  VCT 2025: Pacific Stage 2  Group Stage     Week 1
# 127  VCT 2025: Pacific Stage 2  Group Stage     Week 1
# 128  VCT 2025: Pacific Stage 2  Group Stage     Week 1
# 129  VCT 2025: Pacific Stage 2  Group Stage     Week 1
# 130  VCT 2025: Pacific Stage 2  Group Stage     Week 1
# 131  VCT 2025: Pacific Stage 2  Group Stage     Week 1
# 169    VCT 2025: China Stage 2  Group Stage     Week 2
# 171    VCT 2025: China Stage 2  Group Stage     Week 2
# 173    VCT 2025: China Stage 2  Group Stage     Week 2
# 174    VCT 2025: China Stage 2  Group Stage     Week 2
# ...

# %%
scores_unique = scores_long[~scores_long.duplicated(subset=['Tournament', 'Stage', 'Match Type', 'Teams'], keep=False)]

# %%
scores_unique.shape
# Out:
# (958, 10)

# %%
df_merged = pd.merge(df_clean, scores_unique, on=['Tournament', 'Stage', 'Match Type', 'Teams'], how="left")

# %%
df_merged.shape
# Out:
# (17938, 31)

# %%
df_merged["win"].isna().sum()
# Out:
# np.int64(4660)

# %%
df_final = df_merged[df_merged["win"].notna()]
